# %%
import seaborn, scipy.stats, pylab
seaborn.set_style("white")
# %matplotlib inline

# %%
seaborn.distplot(scipy.stats.norm.rvs(0, 1, size=1000))
seaborn.despine(offset=10)
pylab.plot()
pylab.show()
